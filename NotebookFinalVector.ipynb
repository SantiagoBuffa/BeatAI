# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoBuffa/BeatAI/blob/main/NotebookFinalVector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os, json
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tqdm import tqdm
from google.colab import userdata
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models
from google.colab.patches import cv2_imshow
from scipy.signal import medfilt

# %%
kaggle_username = userdata.get("kaggle_username")
kaggle_key = userdata.get("kaggle_key")

os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)
with open(os.path.expanduser("~/.kaggle/kaggle.json"), "w") as f:
    json.dump({"username": kaggle_username, "key": kaggle_key}, f)

os.chmod(os.path.expanduser("~/.kaggle/kaggle.json"), 0o600)

# !pip install kaggle --quiet
# !kaggle datasets download -d evilspirit05/ecg-analysis -p ./data --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/evilspirit05/ecg-analysis
# License(s): MIT
# Downloading ecg-analysis.zip to ./data
#  92% 763M/826M [00:04<00:01, 42.6MB/s]
# 100% 826M/826M [00:04<00:00, 203MB/s]

# %%
def load_image_rgb(path):
    """
    Carga la imagen, la pasa a gris y aplica un umbral fijo (50).
    Devuelve una imagen 2D binarizada (Blanco y Negro).
    """
    img = cv2.imread(path)
    try:
        if img is None:
            print(f"Error: No se pudo cargar la imagen: {path}")
            return None

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        umbral = 50
        ret, img_limpia = cv2.threshold(gray, umbral, 255, cv2.THRESH_BINARY)

    except Exception as e:
        print(f"Ocurrió un error en load_image_rgb con {path}: {e}")
        return None

    return img_limpia

# %%
def kmeans_1d_weighted(indices, weights, k=3, max_iter=100, tol=1e-3):
    #K-Means 1D para encontrar centros de proyección.
    idx_min, idx_max = indices.min(), indices.max()
    centers = np.linspace(idx_min, idx_max, k)
    for it in range(max_iter):
        dists = np.abs(indices.reshape(-1,1) - centers.reshape(1,-1))
        labels = dists.argmin(axis=1)
        new_centers = np.zeros_like(centers)
        for j in range(k):
            mask = labels == j
            if not np.any(mask):
                new_centers[j] = centers[j]
            else:
                w = weights[mask]
                idxs = indices[mask]
                new_centers[j] = np.sum(idxs * w) / (np.sum(w) + 1e-9)
        shift = np.max(np.abs(new_centers - centers))
        centers = new_centers
        if shift < tol:
            break
    return np.sort(centers)

# %%
def resize_vector(v, target_len):
    if len(v) == target_len:
        return v.copy()
    x_old = np.linspace(0, 1, len(v))
    x_new = np.linspace(0, 1, target_len)
    return np.interp(x_new, x_old, v).astype(np.float32)

# %%
def extract_roi_from_bw(img_bw, min_area=1000):
    # Detecta el borde (Region de interes) basándose en los contornos de la imagen binarizada.
    if img_bw is None:
        return None
    h, w = img_bw.shape
    inverted_img = 255 - img_bw
    contours, _ = cv2.findContours(inverted_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        return img_bw
    big_contour = max(contours, key=cv2.contourArea)
    if cv2.contourArea(big_contour) < min_area:
        return img_bw
    x, y, w_roi, h_roi = cv2.boundingRect(big_contour)
    roi_bw = img_bw[y:y+h_roi, x:x+w_roi]
    return roi_bw

# %%
def split_bw_image_by_projection(roi_bw, num_parts=3):
    #Divide el ROI binarizado en 3 partes usando proyección horizontal.

    h, w = roi_bw.shape
    inverted_img = 255 - roi_bw
    proj = inverted_img.sum(axis=1).astype(float)

    if proj.max() == 0:
        parts = []
        part_height = h // num_parts
        for i in range(num_parts):
            start = i * part_height
            end = (i + 1) * part_height if i < num_parts - 1 else h
            parts.append(roi_bw[start:end, :])
        return parts

    rows = np.arange(len(proj))
    weights = proj / (proj.max() + 1e-9)
    centers = kmeans_1d_weighted(rows, weights, k=num_parts)
    centers = np.array(centers)
    cuts = []
    for i in range(len(centers)-1):
        cuts.append(int(round((centers[i] + centers[i+1]) / 2.0)))

    parts = []
    start = 0
    for c in cuts:
        parts.append(roi_bw[start:c, :])
        start = c
    parts.append(roi_bw[start:h, :])
    return parts

# %%
def part_to_vector_simple(part_bw):
    #Convierte una parte binarizada (B&W) en un vector 1D.
    h, w = part_bw.shape
    if h == 0 or w == 0:
        return np.array([], dtype=float)
    ys = np.zeros(w, dtype=float)
    for col in range(w):
        rows_on = np.where(part_bw[:, col] == 0)[0] # Señal es negra (0)
        if rows_on.size > 0:
            ys[col] = np.median(rows_on)
        else:
            ys[col] = np.nan
    nans = np.isnan(ys)
    if nans.all():
        ys[:] = h / 2.0
    elif nans.any():
        not_nan = ~nans
        x_indices = np.arange(w)
        ys[nans] = np.interp(x_indices[nans], x_indices[not_nan], ys[not_nan])
    ys = (h - 1) - ys
    return ys

# %%
def ecg_bw_photo_to_vector(path, target_len=2048, num_parts=3):
    """
    Función de pipeline final y limpia.
    Toma la ruta de una imagen, la procesa con el pipeline B&W
    y devuelve el vector final.
    """
    img_bw = load_image_rgb(path)
    if img_bw is None:
        # Si la carga falla, devuelve None para que puedas omitirlo
        return None

    # Detectar Borde (ROI)
    roi_bw = extract_roi_from_bw(img_bw)
    if roi_bw is None:
        return None # Omitir si no hay ROI

    # Dividir por Proporciones
    parts = split_bw_image_by_projection(roi_bw, num_parts)

    centered_vectors = []

    # Vectorizar cada parte
    for p in parts:
        vec = part_to_vector_simple(p)
        if vec.size == 0:
            continue

        baseline = np.nanmedian(vec)
        if not np.isnan(baseline):
            vec_centered = vec - baseline
        else:
            vec_centered = vec

        centered_vectors.append(vec_centered)

    if not centered_vectors:
        return None # Omitir si no se pudo

    #Concatenar
    full = np.concatenate(centered_vectors)

    # Normalizar y Filtrar
    mn, mx = np.nanmin(full), np.nanmax(full)
    if mx - mn > 1e-6:
        full = (full - mn) / (mx - mn)
    else:
        full = np.full_like(full, 0.5)

    # Filtro mediano suave (para el texto)
    full = medfilt(full, kernel_size=3)

    # Redimensionar
    final = resize_vector(full, target_len)

    return final

# %%
# !git clone https://github.com/SantiagoBuffa/BeatAI.git
# %cd BeatAI
# Out:
# Cloning into 'BeatAI'...
# remote: Enumerating objects: 1111, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 1111 (delta 52), reused 67 (delta 29), pack-reused 1010 (from 1)
# Receiving objects: 100% (1111/1111), 108.07 MiB | 21.15 MiB/s, done.
# Resolving deltas: 100% (731/731), done.
# /content/BeatAI

# %%
from PIL import Image
def show_vector_simple(path, visualize_steps=False):
    """
    Función de ayuda para ejecutar el pipeline y mostrar el resultado.
    """
    img = cv2.imread(path)
    print("imagen original")
    plt.imshow(img)
    plt.axis('off')
    plt.show()

    img_bw = load_image_rgb(path)
    print("Primer Limpieza")
    plt.imshow(img_bw, cmap='gray')
    plt.axis('off')
    plt.show()

    roi_bw = extract_roi_from_bw(img_bw)
    print("Recorte de Region de interes")
    plt.imshow(roi_bw, cmap='gray')
    plt.axis('off')
    plt.show()
    parts = split_bw_image_by_projection(roi_bw, num_parts=3)
    for i, p in enumerate(parts):
        print(f"Parte {i+1}:")
        plt.imshow(p, cmap='gray')
        plt.axis('off')
        plt.show()
    centered_vectors = []
    for p in parts:
        vec = part_to_vector_simple(p)
        if vec.size == 0:
            continue
        baseline = np.nanmedian(vec)
        if not np.isnan(baseline):
            vec_centered = vec - baseline
        else:
            vec_centered = vec

        centered_vectors.append(vec_centered)

    full = np.concatenate(centered_vectors)
    # Normalizar y Filtrar
    mn, mx = np.nanmin(full), np.nanmax(full)
    if mx - mn > 1e-6:
        full = (full - mn) / (mx - mn)
    else:
        full = np.full_like(full, 0.5)

    # Filtro mediano suave (para el texto)
    full = medfilt(full, kernel_size=3)




    final_vector = ecg_bw_photo_to_vector(path)

    plt.figure(figsize=(30,3))
    plt.plot(final_vector)
    plt.title("Vector Final")
    plt.grid(True)
    plt.show()
    return final_vector

# %%
show_vector_simple("/content/MI(1).jpg",visualize_steps=True);
# Out:
# imagen original
# Primer Limpieza
# Recorte de Region de interes
# Parte 1:
# Parte 2:
# Parte 3:

# %%
def preprocess_dataset_1d(dataset_path, target_len=2048, num_rows=4):

    #Carga todas las imágenes del dataset y genera vectores 1D concatenados.

    train_dir = os.path.join(dataset_path, 'train')
    test_dir = os.path.join(dataset_path, 'test')

    X_train, y_train = [], []
    X_test, y_test = [], []

    class_names = sorted(os.listdir(train_dir))
    print(f"Clases detectadas: {class_names}")

    # TRAIN
    for label, cls in enumerate(class_names):
        cls_dir = os.path.join(train_dir, cls)
        for fname in tqdm(os.listdir(cls_dir), desc=f"Procesando {cls} (train)"):
            path = os.path.join(cls_dir, fname)
            if not fname.lower().endswith(('.jpg', '.png', '.jpeg')):
                continue

            vec = ecg_bw_photo_to_vector(path, target_len)

            X_train.append(vec)
            y_train.append(label)

    # TEST
    for label, cls in enumerate(class_names):
        cls_dir = os.path.join(test_dir, cls)
        for fname in tqdm(os.listdir(cls_dir), desc=f"Procesando {cls} (test)"):
            path = os.path.join(cls_dir, fname)
            if not fname.lower().endswith(('.jpg', '.png', '.jpeg')):
                continue

            vec = ecg_bw_photo_to_vector(path, target_len)

            if vec is None:
                continue
            X_test.append(vec)
            y_test.append(label)

    X_train = np.array(X_train)[..., np.newaxis]
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=len(class_names))
    X_test = np.array(X_test)[..., np.newaxis]
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=len(class_names))

    # VALIDATION a partir de X_train.
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.2, random_state=42, stratify=y_train.argmax(axis=1)
    )

    print(f"X_train: {X_train.shape}, X_val: {X_val.shape}, X_test: {X_test.shape}")
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def build_ecg_1d_model(input_length=2048, num_classes=4):

    #Construye el modelo CNN 1D
    model = models.Sequential([
        layers.Input(shape=(input_length,)),
        # Reshape para añadir el canal (necesario para Conv1D)
        layers.Reshape((input_length, 1)),

        layers.Conv1D(64, 20, activation='relu', padding='same'),
        layers.MaxPooling1D(2),

        layers.Conv1D(128, 10, activation='relu', padding='same'),
        layers.MaxPooling1D(2),

        layers.Conv1D(256, 5, activation='relu', padding='same'),
        layers.GlobalAveragePooling1D(),

        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
dataset_path = "/content/data/ECG_DATA"
TARGET_VECTOR_LENGTH = 2048
NUM_CLASSES = 4


X_train, y_train, X_val, y_val, X_test, y_test = preprocess_dataset_1d(
    dataset_path
)
# Out:
# 📂 Clases detectadas: ['ECG Images of Myocardial Infarction Patients (240x12=2880)', 'ECG Images of Patient that have History of MI (172x12=2064)', 'ECG Images of Patient that have abnormal heartbeat (233x12=2796)', 'Normal Person ECG Images (284x12=3408)']
# Procesando ECG Images of Myocardial Infarction Patients (240x12=2880) (train): 100%|██████████| 956/956 [02:51<00:00,  5.56it/s]
# Procesando ECG Images of Patient that have History of MI (172x12=2064) (train): 100%|██████████| 516/516 [01:31<00:00,  5.61it/s]
# Procesando ECG Images of Patient that have abnormal heartbeat (233x12=2796) (train): 100%|██████████| 699/699 [02:04<00:00,  5.63it/s]
# Procesando Normal Person ECG Images (284x12=3408) (train): 100%|██████████| 852/852 [02:32<00:00,  5.58it/s]
# Procesando ECG Images of Myocardial Infarction Patients (240x12=2880) (test): 100%|██████████| 239/239 [00:42<00:00,  5.57it/s]
# Procesando ECG Images of Patient that have History of MI (172x12=2064) (test): 100%|██████████| 172/172 [00:31<00:00,  5.46it/s]
# Procesando ECG Images of Patient that have abnormal heartbeat (233x12=2796) (test): 100%|██████████| 233/233 [00:41<00:00,  5.58it/s]
# Procesando Normal Person ECG Images (284x12=3408) (test): 100%|██████████| 284/284 [00:50<00:00,  5.62it/s]
# ✅ X_train: (2418, 2048, 1), X_val: (605, 2048, 1), X_test: (928, 2048, 1)

# %%
# Construir el modelo
model = build_ecg_1d_model(
    input_length=TARGET_VECTOR_LENGTH,
    num_classes=NUM_CLASSES
)

# %%
model.summary()

print("\nIniciando entrenamiento...")
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)]
)

# Evaluar en el conjunto de test
print("\nEvaluando en el conjunto de test...")
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)               │ (None, 2048, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 2048, 64)       │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 1024, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 1024, 128)      │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 512, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 512, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 280,900 (1.07 MB)
#  Trainable params: 280,900 (1.07 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando entrenamiento...
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 59s 751ms/step - accuracy: 0.2961 - loss: 1.3746 - val_accuracy: 0.3157 - val_loss: 1.3365
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 740ms/step - accuracy: 0.3691 - loss: 1.3127 - val_accuracy: 0.4033 - val_loss: 1.2434
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 744ms/step - accuracy: 0.4126 - loss: 1.2444 - val_accuracy: 0.4628 - val_loss: 1.1571
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 80s 721ms/step - accuracy: 0.4868 - loss: 1.1422 - val_accuracy: 0.5438 - val_loss: 1.0741
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 712ms/step - accuracy: 0.5050 - loss: 1.1175 - val_accuracy: 0.5521 - val_loss: 1.0678
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 58s 763ms/step - accuracy: 0.5279 - loss: 1.0756 - val_accuracy: 0.4959 - val_loss: 1.1283
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 78s 718ms/step - accuracy: 0.5061 - loss: 1.1132 - val_accuracy: 0.4595 - val_loss: 1.1894
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 717ms/step - accuracy: 0.5545 - loss: 1.0480 - val_accuracy: 0.5769 - val_loss: 0.9892
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 741ms/step - accuracy: 0.5948 - loss: 0.9729 - val_accuracy: 0.6165 - val_loss: 0.9195
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 57s 749ms/step - accuracy: 0.6338 - loss: 0.8854 - val_accuracy: 0.6000 - val_loss: 0.7799
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 57s 751ms/step - accuracy: 0.6429 - loss: 0.8083 - val_accuracy: 0.7769 - val_loss: 0.5836
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 734ms/step - accuracy: 0.7373 - loss: 0.6633 - val_accuracy: 0.7785 - val_loss: 0.6123
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 726ms/step - accuracy: 0.7489 - loss: 0.6123 - val_accuracy: 0.6727 - val_loss: 0.6728
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 749ms/step - accuracy: 0.7151 - loss: 0.6825 - val_accuracy: 0.8231 - val_loss: 0.4976
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 60s 786ms/step - accuracy: 0.7568 - loss: 0.6025 - val_accuracy: 0.7570 - val_loss: 0.6061
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 79s 742ms/step - accuracy: 0.7964 - loss: 0.5001 - val_accuracy: 0.7504 - val_loss: 0.5983
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 57s 746ms/step - accuracy: 0.7605 - loss: 0.5945 - val_accuracy: 0.8298 - val_loss: 0.4609
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 737ms/step - accuracy: 0.7985 - loss: 0.5016 - val_accuracy: 0.8562 - val_loss: 0.3958
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 727ms/step - accuracy: 0.8283 - loss: 0.4338 - val_accuracy: 0.8777 - val_loss: 0.3938
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 734ms/step - accuracy: 0.8378 - loss: 0.4333 - val_accuracy: 0.8760 - val_loss: 0.3580
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 725ms/step - accuracy: 0.8767 - loss: 0.3426 - val_accuracy: 0.9174 - val_loss: 0.2548
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 57s 749ms/step - accuracy: 0.8808 - loss: 0.3180 - val_accuracy: 0.9207 - val_loss: 0.2714
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 735ms/step - accuracy: 0.8874 - loss: 0.3208 - val_accuracy: 0.9223 - val_loss: 0.2907
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 87s 809ms/step - accuracy: 0.8703 - loss: 0.3400 - val_accuracy: 0.9025 - val_loss: 0.2782
# Epoch 25/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 722ms/step - accuracy: 0.8986 - loss: 0.3012 - val_accuracy: 0.9223 - val_loss: 0.2337
# Epoch 26/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 728ms/step - accuracy: 0.9002 - loss: 0.2705 - val_accuracy: 0.9388 - val_loss: 0.2247
# Epoch 27/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 721ms/step - accuracy: 0.9148 - loss: 0.2594 - val_accuracy: 0.9455 - val_loss: 0.1858
# Epoch 28/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 723ms/step - accuracy: 0.9176 - loss: 0.2337 - val_accuracy: 0.9223 - val_loss: 0.2327
# Epoch 29/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 737ms/step - accuracy: 0.9112 - loss: 0.2605 - val_accuracy: 0.9207 - val_loss: 0.2013
# Epoch 30/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 734ms/step - accuracy: 0.9401 - loss: 0.1925 - val_accuracy: 0.9504 - val_loss: 0.1481
# Epoch 31/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 718ms/step - accuracy: 0.9307 - loss: 0.2141 - val_accuracy: 0.9438 - val_loss: 0.1548
# Epoch 32/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 725ms/step - accuracy: 0.9418 - loss: 0.1771 - val_accuracy: 0.9306 - val_loss: 0.1763
# Epoch 33/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 61s 801ms/step - accuracy: 0.9336 - loss: 0.1911 - val_accuracy: 0.9702 - val_loss: 0.1255
# Epoch 34/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 77s 735ms/step - accuracy: 0.9136 - loss: 0.2392 - val_accuracy: 0.9620 - val_loss: 0.1400
# Epoch 35/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 749ms/step - accuracy: 0.9366 - loss: 0.1803 - val_accuracy: 0.9636 - val_loss: 0.1226
# Epoch 36/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 736ms/step - accuracy: 0.9592 - loss: 0.1413 - val_accuracy: 0.9636 - val_loss: 0.1354
# Epoch 37/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 57s 749ms/step - accuracy: 0.9502 - loss: 0.1351 - val_accuracy: 0.9488 - val_loss: 0.1390
# Epoch 38/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 745ms/step - accuracy: 0.9510 - loss: 0.1383 - val_accuracy: 0.9488 - val_loss: 0.1517
# Epoch 39/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 57s 750ms/step - accuracy: 0.9327 - loss: 0.1781 - val_accuracy: 0.9669 - val_loss: 0.1241
# Epoch 40/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 80s 725ms/step - accuracy: 0.9493 - loss: 0.1424 - val_accuracy: 0.9603 - val_loss: 0.1090
# Epoch 41/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 720ms/step - accuracy: 0.9528 - loss: 0.1410 - val_accuracy: 0.9702 - val_loss: 0.1066
# Epoch 42/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 740ms/step - accuracy: 0.9559 - loss: 0.1355 - val_accuracy: 0.9785 - val_loss: 0.0931
# Epoch 43/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 748ms/step - accuracy: 0.9565 - loss: 0.1149 - val_accuracy: 0.9653 - val_loss: 0.1188
# Epoch 44/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 726ms/step - accuracy: 0.9650 - loss: 0.1095 - val_accuracy: 0.9653 - val_loss: 0.0949
# Epoch 45/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 724ms/step - accuracy: 0.9656 - loss: 0.1004 - val_accuracy: 0.9669 - val_loss: 0.1061
# Epoch 46/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 723ms/step - accuracy: 0.9623 - loss: 0.1038 - val_accuracy: 0.9669 - val_loss: 0.1189
# Epoch 47/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 746ms/step - accuracy: 0.9581 - loss: 0.1235 - val_accuracy: 0.9488 - val_loss: 0.1492
# Epoch 48/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 729ms/step - accuracy: 0.9462 - loss: 0.1546 - val_accuracy: 0.8397 - val_loss: 0.4788
# Epoch 49/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 730ms/step - accuracy: 0.9186 - loss: 0.2511 - val_accuracy: 0.9686 - val_loss: 0.0966
# Epoch 50/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 80s 711ms/step - accuracy: 0.9592 - loss: 0.1039 - val_accuracy: 0.9603 - val_loss: 0.1248
# Epoch 51/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 735ms/step - accuracy: 0.9688 - loss: 0.1045 - val_accuracy: 0.9769 - val_loss: 0.0871
# Epoch 52/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 737ms/step - accuracy: 0.9739 - loss: 0.0895 - val_accuracy: 0.9702 - val_loss: 0.0925
# Epoch 53/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 736ms/step - accuracy: 0.9618 - loss: 0.1079 - val_accuracy: 0.9835 - val_loss: 0.0783
# Epoch 54/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 737ms/step - accuracy: 0.9745 - loss: 0.0813 - val_accuracy: 0.9785 - val_loss: 0.0715
# Epoch 55/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 80s 718ms/step - accuracy: 0.9781 - loss: 0.0705 - val_accuracy: 0.9802 - val_loss: 0.0806
# Epoch 56/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 732ms/step - accuracy: 0.9726 - loss: 0.0905 - val_accuracy: 0.9802 - val_loss: 0.0686
# Epoch 57/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 715ms/step - accuracy: 0.9769 - loss: 0.0693 - val_accuracy: 0.9736 - val_loss: 0.0699
# Epoch 58/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 736ms/step - accuracy: 0.9800 - loss: 0.0661 - val_accuracy: 0.9802 - val_loss: 0.0601
# Epoch 59/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 735ms/step - accuracy: 0.9740 - loss: 0.0756 - val_accuracy: 0.9653 - val_loss: 0.0953
# Epoch 60/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 715ms/step - accuracy: 0.9766 - loss: 0.0743 - val_accuracy: 0.9802 - val_loss: 0.0591
# Epoch 61/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 713ms/step - accuracy: 0.9853 - loss: 0.0479 - val_accuracy: 0.9306 - val_loss: 0.2052
# Epoch 62/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 701ms/step - accuracy: 0.9657 - loss: 0.0963 - val_accuracy: 0.9835 - val_loss: 0.0745
# Epoch 63/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 694ms/step - accuracy: 0.9814 - loss: 0.0521 - val_accuracy: 0.9736 - val_loss: 0.0730
# Epoch 64/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 727ms/step - accuracy: 0.9824 - loss: 0.0602 - val_accuracy: 0.9736 - val_loss: 0.0672
# Epoch 65/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 713ms/step - accuracy: 0.9800 - loss: 0.0650 - val_accuracy: 0.9884 - val_loss: 0.0596
# Epoch 66/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 705ms/step - accuracy: 0.9786 - loss: 0.0592 - val_accuracy: 0.9851 - val_loss: 0.0474
# Epoch 67/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 709ms/step - accuracy: 0.9821 - loss: 0.0550 - val_accuracy: 0.9851 - val_loss: 0.0471
# Epoch 68/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 718ms/step - accuracy: 0.9787 - loss: 0.0621 - val_accuracy: 0.9802 - val_loss: 0.0663
# Epoch 69/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 709ms/step - accuracy: 0.9765 - loss: 0.0714 - val_accuracy: 0.9818 - val_loss: 0.0611
# Epoch 70/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 710ms/step - accuracy: 0.9809 - loss: 0.0577 - val_accuracy: 0.9868 - val_loss: 0.0473
# Epoch 71/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 718ms/step - accuracy: 0.9840 - loss: 0.0470 - val_accuracy: 0.9868 - val_loss: 0.0422
# Epoch 72/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 708ms/step - accuracy: 0.9889 - loss: 0.0353 - val_accuracy: 0.9884 - val_loss: 0.0435
# Epoch 73/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 710ms/step - accuracy: 0.9790 - loss: 0.0535 - val_accuracy: 0.9355 - val_loss: 0.1280
# Epoch 74/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 712ms/step - accuracy: 0.9734 - loss: 0.0777 - val_accuracy: 0.9818 - val_loss: 0.0551
# Epoch 75/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 708ms/step - accuracy: 0.9820 - loss: 0.0502 - val_accuracy: 0.9851 - val_loss: 0.0483
# Epoch 76/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 713ms/step - accuracy: 0.9794 - loss: 0.0498 - val_accuracy: 0.9868 - val_loss: 0.0399
# Epoch 77/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 709ms/step - accuracy: 0.9846 - loss: 0.0437 - val_accuracy: 0.9851 - val_loss: 0.0455
# Epoch 78/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 53s 697ms/step - accuracy: 0.9663 - loss: 0.0845 - val_accuracy: 0.9785 - val_loss: 0.0657
# Epoch 79/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 721ms/step - accuracy: 0.9858 - loss: 0.0475 - val_accuracy: 0.9636 - val_loss: 0.1019
# Epoch 80/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 53s 695ms/step - accuracy: 0.9843 - loss: 0.0619 - val_accuracy: 0.9818 - val_loss: 0.0570
# Epoch 81/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 695ms/step - accuracy: 0.9854 - loss: 0.0500 - val_accuracy: 0.9868 - val_loss: 0.0491
# Epoch 82/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 705ms/step - accuracy: 0.9882 - loss: 0.0438 - val_accuracy: 0.9934 - val_loss: 0.0322
# Epoch 83/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 730ms/step - accuracy: 0.9876 - loss: 0.0434 - val_accuracy: 0.9835 - val_loss: 0.0511
# Epoch 84/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 732ms/step - accuracy: 0.9858 - loss: 0.0481 - val_accuracy: 0.9950 - val_loss: 0.0316
# Epoch 85/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 709ms/step - accuracy: 0.9869 - loss: 0.0392 - val_accuracy: 0.9686 - val_loss: 0.0839
# Epoch 86/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 54s 711ms/step - accuracy: 0.9904 - loss: 0.0307 - val_accuracy: 0.9868 - val_loss: 0.0351
# Epoch 87/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 732ms/step - accuracy: 0.9913 - loss: 0.0290 - val_accuracy: 0.9901 - val_loss: 0.0325
# Epoch 88/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 731ms/step - accuracy: 0.9893 - loss: 0.0352 - val_accuracy: 0.9769 - val_loss: 0.0681
# Epoch 89/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 56s 732ms/step - accuracy: 0.9858 - loss: 0.0465 - val_accuracy: 0.9901 - val_loss: 0.0290
# Epoch 90/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 717ms/step - accuracy: 0.9928 - loss: 0.0263 - val_accuracy: 0.9934 - val_loss: 0.0234
# Epoch 91/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 81s 709ms/step - accuracy: 0.9894 - loss: 0.0246 - val_accuracy: 0.9950 - val_loss: 0.0200
# Epoch 92/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 84s 730ms/step - accuracy: 0.9979 - loss: 0.0119 - val_accuracy: 0.9950 - val_loss: 0.0236
# Epoch 93/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 80s 713ms/step - accuracy: 0.9930 - loss: 0.0231 - val_accuracy: 0.9934 - val_loss: 0.0152
# Epoch 94/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 722ms/step - accuracy: 0.9949 - loss: 0.0170 - val_accuracy: 0.9818 - val_loss: 0.0470
# Epoch 95/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 83s 742ms/step - accuracy: 0.9905 - loss: 0.0301 - val_accuracy: 0.9934 - val_loss: 0.0256
# Epoch 96/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 719ms/step - accuracy: 0.9896 - loss: 0.0256 - val_accuracy: 0.9669 - val_loss: 0.0745
# Epoch 97/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 55s 724ms/step - accuracy: 0.9915 - loss: 0.0288 - val_accuracy: 0.9868 - val_loss: 0.0373
# Epoch 98/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 79s 697ms/step - accuracy: 0.9897 - loss: 0.0326 - val_accuracy: 0.9901 - val_loss: 0.0252
# Epoch 99/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 85s 737ms/step - accuracy: 0.9842 - loss: 0.0564 - val_accuracy: 0.9917 - val_loss: 0.0239
# Epoch 100/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 82s 734ms/step - accuracy: 0.9963 - loss: 0.0193 - val_accuracy: 0.9901 - val_loss: 0.0307
#
# Evaluando en el conjunto de test (limpio)...
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.9972 - loss: 0.0079
# Test Loss: 0.0121
# Test Accuracy: 99.57%

# %%
def show_graphs(history):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.subplot(1,2,2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

show_graphs(history)

# %%
model.save("ecg_modelVectorFinal.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#!git push origin main
